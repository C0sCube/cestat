# %%
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
from dateutil.parser import parse
import importlib
import app.prg_ngt
from app.konstant import ROOT_DIR
importlib.reload(app.prg_ngt)



from app.prg_ngt import NGT
from app.utils import Helper

utils = Helper()
config_path =os.path.join(ROOT_DIR,"config","config_ngt.json5") #r"C:\Users\rando\Office Projects\rep_cestat\config\config_ngt.json5" 
if __name__ == "__main__":
    config = utils.load_json5(config_path)
    ngt = NGT(config)
    df = ngt.get_data(retries=10)
    
    if not df.empty:
        df1 = ngt.filter_data(df)
        print("Rows fetched:", len(df1))
        df1.head()

        # ---- save ----
        df1.to_excel("ngt_orders.xlsx", index=False)
        print("Saved as ngt_orders.xlsx")
        
    else:
        print("NO tables fetched.")
        df.to_excel("ngt_orders.xlsx", index=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Predict: evdk3q
# Rows fetched: 189
# Saved as ngt_orders.xlsx

# %%
from app.utils import Helper

utils = Helper()
utils.generate_dates("%d-%m-%Y")
# Out:
# ('01-05-2026', '02-05-2026')
