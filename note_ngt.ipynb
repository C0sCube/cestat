# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from dateutil.parser import parse
import importlib
import app.prg_ngt

importlib.reload(app.prg_ngt)



from app.prg_ngt import NGT
from app.utils import Helper

utils = Helper()
config_path =r"C:\Users\kaustubh.keny\Projects\OFFICE PROJECTS\CESTAT\docs\config_ngt.json5" 
if __name__ == "__main__":
    config = utils.load_json5(config_path)
    ngt = NGT(config)
    df = ngt.get_data(retries=10)

    # ---- preview ----
    print("Rows fetched:", len(df))
    df.head()

    # ---- save ----
    df.to_excel("ngt_orders.xlsx", index=False)
    print("Saved as ngt_orders.xlsx")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
